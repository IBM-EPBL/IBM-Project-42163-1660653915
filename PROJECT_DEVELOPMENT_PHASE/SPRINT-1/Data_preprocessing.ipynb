# %% [markdown]
# **TEAM ID   : PNT2022TMID54247/
# Team Size   : 4/
# Team Leader : JAGADEESH R/
# Team member : KARTHIK K/
# Team member : HARIHARAN C/
# Team member : DEEPAK RAJ S/**

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
import pandas as pd

df =pd.read_csv("drive/My Drive/Colab Notebooks/IBM DATA SET/sample_sub.csv")
df.head()
# Out:
#    case_id  Stay
# 0   318439  0-10
# 1   318440  0-10
# 2   318441  0-10
# 3   318442  0-10
# 4   318443  0-10

# %% [markdown]
# **TEAM ID   : PNT2022TMID54247/
# Team Size   : 4/
# Team Leader : JAGADEESH R/
# Team member : KARTHIK K/
# Team member : HARIHARAN C/
# Team member : DEEPAK RAJ S/**

# %%
df =pd.read_csv("drive/My Drive/Colab Notebooks/IBM DATA SET/test_data.csv")
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  A        2.0      17006                2.0
# ...

# %% [markdown]
# **TEAM ID   : PNT2022TMID54247/
# Team Size   : 4/
# Team Leader : JAGADEESH R/
# Team member : KARTHIK K/
# Team member : HARIHARAN C/
# Team member : DEEPAK RAJ S/**

# %%
df =pd.read_csv("drive/My Drive/Colab Notebooks/IBM DATA SET/train_data.csv")
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %% [markdown]
# **TEAM ID   : PNT2022TMID54247/
# Team Size   : 4/
# Team Leader : JAGADEESH R/
# Team member : KARTHIK K/
# Team member : HARIHARAN C/
# Team member : DEEPAK RAJ S/**

# %%
df =pd.read_csv("drive/My Drive/Colab Notebooks/IBM DATA SET/train_data_dictionary.csv")
df.head()
# Out:
#                  Column                           Description
# 0               case_id        Case_ID registered in Hospital
# 1         Hospital_code          Unique code for the Hospital
# 2    Hospital_type_code  Unique code for the type of Hospital
# 3    City_Code_Hospital             City Code of the Hospital
# 4  Hospital_region_code           Region Code of the Hospital

# %% [markdown]
# **TEAM ID   : PNT2022TMID54247/
# Team Size   : 4/
# Team Leader : JAGADEESH R/
# Team member : KARTHIK K/
# Team member : HARIHARAN C/
# Team member : DEEPAK RAJ S/**
